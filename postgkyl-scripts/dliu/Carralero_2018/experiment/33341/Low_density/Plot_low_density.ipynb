# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dir_ne = './Electron_density/'
file_ne = 'ne_background_Libeam_Low_dens_33341.csv'

dir_Te = './Electron_temperature/'
file_Te = 'Te_background_TS_Low_dens_33341.csv'

df_ne = pd.read_csv(dir_ne+file_ne)
df_Te = pd.read_csv(dir_Te+file_Te)

print(df_ne.head())
print(df_Te.head())
# Out:
#    RRsep[mm]       ne[m-3]
# 0  81.187983  2.001780e+17
# 1  75.927992  2.172398e+17
# 2  71.108122  2.323489e+17
# 3  66.318055  2.443833e+17
# 4  61.637898  2.514426e+17
#     RRsep[mm]    Te_u[eV]
# 0 -106.401099 -106.401099
# 1 -101.926202 -101.926202
# 2  -97.428865  -97.428865
# 3  -92.907329  -92.907329
# 4  -88.362406  -88.362406

# %%
# Access the column at index 0 (the first column)
RRsep_ne = df_ne.iloc[:, 0]
ne = df_ne.iloc[:, 1]
print(np.shape(ne))

RRsep_Te = df_Te.iloc[:, 0]
Te = df_Te.iloc[:, 1]
print(np.shape(Te))
# Out:
# (35,)
# (38,)

# %%
plt.scatter(RRsep_ne, ne)
plt.scatter(RRsep_Te, Te)
