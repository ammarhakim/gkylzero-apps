# %%
import numpy as np
import matplotlib.pyplot as plt

lblSize = 14
ttlSize = 16
tickSize = 12
lgdSize = 12
txtSize = 14

iter = np.arange(0, 9)

error_max1 = [1.34575753e-09, 4.29513871e-11, 6.32065051e-13, 9.53203294e-15, 
              3.00336309e-16, 2.27439146e-16, 6.38579141e-16, 5.10280136e-16, 4.08224109e-17]
error_max2 = [1.80080565e-03, 2.61125374e-05, 3.80714782e-07, 5.55117465e-09,
              8.09393039e-11, 1.17819325e-12, 2.07030762e-14, 4.70524460e-16, 4.70524460e-16]

fig = plt.figure(figsize=[6.4, 4.8])
plt.plot(iter, error_max1, 'r', marker='.', linestyle='-', label=r'$(|\Delta u_{\parallel}|/|u_{\parallel}|)_{max}$')
plt.plot(iter, error_max2, 'b', marker='.', linestyle='-', label=r'$(|\Delta v_{t}^2|/v_{t,ref}^2)_{max}$')
#plt.hlines(1.0e-12, 0, 12, 'k', linewidth=0.5)
plt.xlim(0, 8)
plt.ylim(1.0e-16, 1.0)
plt.yscale('log')
plt.xlabel('iteration', fontsize=lblSize)
plt.ylabel('error', fontsize=lblSize)
plt.tick_params(labelsize=tickSize)
plt.legend(fontsize=lblSize)

plt.tight_layout()
plt.savefig('error-iteration-step1-stage1-correct2.png')
