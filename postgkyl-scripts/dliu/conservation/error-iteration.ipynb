# %%
import numpy as np
import matplotlib.pyplot as plt

lblSize = 14
ttlSize = 16
tickSize = 12
lgdSize = 12
txtSize = 14

iter = np.arange(0, 10)

error_max1 = [5.96375500e-09, 1.99722105e-10, 3.08890060e-12, 4.77615347e-14, 8.71136942e-16, 
              1.97457707e-16, 7.89830827e-16, 4.29760891e-16, 4.64606369e-17, 6.96909554e-17]
error_max2 = [1.90833081e-03, 2.90849419e-05, 4.45827125e-07, 6.83443265e-09, 1.04769470e-10,
              1.60644664e-12, 2.22426287e-14, 1.55542858e-16, 1.55542858e-16, 3.11085716e-16]

fig = plt.figure(figsize=[6.4, 4.8])
plt.plot(iter, error_max1, 'r', marker='.', linestyle='-', label=r'$(|\Delta u_{\parallel}|/|u_{\parallel}|)_{max}$')
plt.plot(iter, error_max2, 'b', marker='.', linestyle='-', label=r'$(|\Delta v_{t}^2|/v_{t,ref}^2)_{max}$')
plt.hlines(1.0e-16, 0.0, 8.0, 'k', '--')
plt.xlim(0.0, 8.0)
plt.ylim(1.0e-18, 0.01)
plt.yscale('log')
plt.xlabel('iteration', fontsize=lblSize)
plt.ylabel('error', fontsize=lblSize)
plt.tick_params(labelsize=tickSize)
plt.legend(fontsize=lblSize)

plt.tight_layout()
plt.savefig('error-iteration-step1-stage1-correct2.png')
